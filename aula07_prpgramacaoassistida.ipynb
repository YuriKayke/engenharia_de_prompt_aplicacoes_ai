# %% [markdown]
# #Aula: Programação Assistida
# Nome: Yuri Kayke (Turma sextou)

# %%
numeros = [1,2,3] # Define uma lista de números inteiros.
soma = 0 # Inicializa a variável 'soma' com zero.

# Itera sobre cada número na lista 'numeros'.
for num in numeros:
  soma += num # Adiciona o número atual à variável 'soma'.

print(soma) # Imprime o valor final da soma.
# Out:
# 6

# %% [markdown]
# Eh primo

# %%
import math

def eh_primo(n):
    if n < 2:
        return False
    if n == 2:
        return True
    if n % 2 == 0: # Todos os outros números pares não são primos
        return False
    # Verifica apenas divisores ímpares de 3 até a raiz quadrada de n
    for i in range(3, int(math.sqrt(n)) + 1, 2):
        if n % i == 0:
            return False
    return True

print(eh_primo(7)) # Deve ser True
print(eh_primo(2)) # Deve ser True
print(eh_primo(1)) # Deve ser False
print(eh_primo(4)) # Deve ser False
print(eh_primo(9)) # Deve ser False
print(eh_primo(17)) # Deve ser True

# %% [markdown]
# Inversão String

# %%
def inverte_texto(texto):
  # Utiliza o fatiamento de string (slicing) para inverter o texto.
  # [::-1] cria uma cópia da string original, mas com os caracteres em ordem inversa.
  # O primeiro e segundo ':' indicam que a fatia começa do início e vai até o final da string.
  # O '-1' indica que a string deve ser percorrida de trás para frente (passo negativo).
  return texto[::-1]

print (inverte_texto('ola'))
# Out:
# alo

# %% [markdown]
# # Mini projeto
